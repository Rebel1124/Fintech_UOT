# %% [markdown]
# # Column Manipulation of Pandas DataFrames

# %% [markdown]
# ### 1. Import libraries and dependencies

# %%
# Import pandas, pathlib, and numpy libraries
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# ### 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib libary to set the path to the CSV
csvpath=('../Resources/people.csv')

# %% [markdown]
# ### 3. Read the CSV into a Pandas DataFrame and Display a Few Rows

# %%
df = pd.read_csv(csvpath)

# %%
df.head()
# Out:
#     id first_name    last_name                            email  gender  \
# 0  1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1  2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2  3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3  4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4  5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                             uni_grad           job_title  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Income
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %%
# Use the file path to read the CSV into a DataFrame and display a few rows
df.head()
# Out:
#     id first_name    last_name                            email  gender  \
# 0  1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1  2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2  3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3  4.0     Cullie       Putten               cputten3@nymag.com    Male
# 4  5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                             uni_grad           job_title  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Income
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %% [markdown]
# ### 4. View Column Names

# %%
df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'uni_grad',
#        'job_title', 'Income'],
#       dtype='object')

# %%
# Use the `columns` attribute to output the column names
df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'uni_grad',
#        'job_title', 'Income'],
#       dtype='object')

# %% [markdown]
# ### 5. View Column Data Types

# %%
df.dtypes
# Out:
# id            float64
# first_name     object
# last_name      object
# email          object
# gender         object
# uni_grad       object
# job_title      object
# Income        float64
# dtype: object

# %%
# Use the `dtypes` attribute to output the column names and data types
df.dtypes
# Out:
# id            float64
# first_name     object
# last_name      object
# email          object
# gender         object
# uni_grad       object
# job_title      object
# Income        float64
# dtype: object

# %% [markdown]
# ### 6. Rename Columns Using List

# %%
newColumns = ['Person_ID', 'First_Name', 'Last_Name', 'Email', 'Gender', 'University', 'Occupation', 'Salary']

# %%
# Set the `columns` attribute to a new list of column names
# Out:
#    Person_ID First_Name    Last_Name                            Email  Gender  \
# 0        1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1        2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2        3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3        4.0     Cullie       Putten               cputten3@nymag.com    Male
# 4        5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %% [markdown]
# ### 7. Rename Columns Using Dictionary

# %%
df.columns = newColumns

# %%
df.head()
# Out:
#    Person_ID First_Name    Last_Name                            Email  Gender  \
# 0        1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1        2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2        3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3        4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4        5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %%
# Use the `rename` function and set the `columns` parameter to a dictionary of new column names
# Out:
#    Person_ID First_Name    Last_Name                            Email  Gender  \
# 0        1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1        2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2        3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3        4.0     Cullie       Putten               cputten3@nymag.com    Male
# 4        5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %% [markdown]
# ### 8. Re-order Columns

# %%
newdf = df[['Person_ID', 'Last_Name', 'First_Name', 'Gender', 'University', 'Occupation', 'Salary', 'Email']]

# %%
newdf.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0          NaN     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email
# 0  58135.0  klenormand0@businessinsider.com
# 1  96053.0              hrupke1@reuters.com
# 2  59196.0      gdalgarnowch2@microsoft.com
# 3  88493.0               cputten3@nymag.com
# 4  89073.0       astrangman4@bravesites.com

# %%
# Use a list of re-ordered column names to alter the column order of the original DataFrame
newdf = df[['Person_ID', 'Last_Name', 'First_Name', 'Gender', 'University', 'Occupation', 'Salary', 'Email']]
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0       Putten     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email
# 0  58135.0  klenormand0@businessinsider.com
# 1  96053.0              hrupke1@reuters.com
# 2  59196.0      gdalgarnowch2@microsoft.com
# 3  88493.0               cputten3@nymag.com
# 4  89073.0       astrangman4@bravesites.com

# %% [markdown]
# ### 9. Create Additional Column

# %%
age = np.random.randint(low=22, high=65, size=1000)

# %%
age
# Out:
# array([38, 37, 23, 31, 28, 34, 59, 28, 22, 35, 51, 32, 63, 64, 58, 30, 30,
#        57, 31, 25, 44, 33, 23, 56, 61, 38, 49, 23, 36, 36, 62, 23, 52, 61,
#        62, 63, 46, 45, 51, 60, 30, 60, 62, 31, 46, 44, 41, 62, 22, 57, 61,
#        60, 39, 46, 39, 31, 42, 59, 63, 42, 49, 56, 22, 47, 27, 31, 56, 53,
#        32, 55, 49, 38, 47, 41, 35, 23, 48, 33, 57, 57, 41, 34, 44, 51, 43,
#        25, 46, 50, 36, 42, 57, 49, 51, 62, 50, 60, 35, 52, 33, 29, 60, 31,
#        52, 51, 60, 49, 24, 22, 31, 43, 48, 35, 35, 47, 32, 39, 26, 44, 44,
#        47, 31, 26, 27, 53, 32, 36, 27, 40, 49, 37, 32, 45, 28, 36, 32, 32,
#        55, 28, 42, 40, 63, 33, 50, 56, 49, 63, 26, 28, 39, 44, 25, 64, 25,
#        59, 57, 26, 58, 56, 30, 22, 61, 24, 57, 30, 22, 38, 25, 35, 44, 54,
#        45, 36, 24, 33, 59, 62, 23, 23, 62, 24, 48, 42, 55, 45, 28, 54, 54,
#        29, 30, 47, 33, 61, 51, 39, 56, 34, 29, 29, 45, 28, 62, 39, 53, 62,
#        41, 32, 54, 62, 35, 46, 43, 40, 25, 42, 40, 39, 46, 50, 39, 43, 43,
#        23, 32, 28, 37, 46, 59, 25, 54, 60, 42, 38, 64, 38, 42, 39, 36, 55,
#        46, 29, 36, 43, 29, 56, 31, 23, 56, 28, 56, 38, 57, 55, 22, 42, 41,
#        54, 47, 57, 46, 63, 48, 38, 23, 64, 54, 27, 58, 23, 51, 44, 62, 54,
#        56, 33, 27, 50, 25, 38, 26, 43, 37, 29, 32, 39, 26, 47, 50, 63, 64,
#        41, 41, 36, 53, 51, 30, 38, 32, 48, 39, 34, 54, 45, 27, 56, 59, 62,
#        40, 24, 62, 43, 22, 28, 37, 23, 53, 27, 62, 25, 27, 35, 36, 52, 32,
#        44, 34, 63, 47, 48, 34, 42, 40, 53, 56, 63, 36, 36, 28, 41, 60, 25,
#        49, 59, 41, 60, 32, 49, 35, 39, 54, 61, 61, 44, 54, 59, 43, 32, 39,
#        39, 29, 63, 43, 28, 22, 54, 55, 24, 44, 42, 53, 62, 31, 42, 24, 39,
#        24, 55, 58, 45, 22, 51, 39, 35, 45, 34, 45, 35, 50, 35, 56, 34, 47,
#        29, 22, 29, 59, 42, 49, 49, 31, 45, 51, 44, 35, 22, 52, 62, 38, 63,
#        48, 50, 26, 26, 25, 43, 49, 24, 34, 62, 48, 39, 58, 63, 36, 51, 22,
#        63, 30, 57, 35, 36, 54, 36, 45, 43, 53, 47, 58, 33, 26, 63, 23, 40,
#        25, 62, 24, 27, 22, 51, 64, 27, 45, 63, 61, 51, 22, 24, 46, 54, 50,
#        57, 41, 48, 36, 29, 37, 33, 28, 23, 52, 64, 61, 36, 29, 64, 35, 47,
#        63, 31, 25, 60, 55, 60, 53, 45, 64, 48, 59, 42, 36, 25, 25, 34, 38,
#        35, 52, 64, 43, 49, 41, 57, 31, 62, 56, 36, 34, 37, 25, 51, 55, 41,
#        64, 23, 34, 24, 48, 31, 37, 59, 48, 42, 43, 34, 41, 29, 62, 59, 58,
#        41, 37, 50, 25, 62, 62, 49, 30, 55, 51, 49, 23, 59, 44, 24, 62, 62,
#        38, 38, 64, 61, 54, 36, 54, 24, 33, 44, 33, 51, 36, 42])

# %%
newage = pd.DataFrame(age)

# %%
newdf['Age_Copy'] =np.random.randint(low=22, high=65, size=1000)
# Out:
# C:\Users\desig\AppData\Local\Temp/ipykernel_23892/3084627622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Age_Copy'] =np.random.randint(low=22, high=65, size=1000)

# %%
newdf.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0          NaN     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age_Copy
# 0  58135.0  klenormand0@businessinsider.com        25
# 1  96053.0              hrupke1@reuters.com        28
# 2  59196.0      gdalgarnowch2@microsoft.com        61
# 3  88493.0               cputten3@nymag.com        28
# 4  89073.0       astrangman4@bravesites.com        40

# %%
newdf['age'] = newdf['Age_Copy']
# Out:
# C:\Users\desig\AppData\Local\Temp/ipykernel_23892/878324963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['age'] = newdf['Age_Copy']

# %%
# Use the `randint` function to randomly generate an `Age` from 22 to 65 for 1000 rows
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0       Putten     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age  Age_Copy
# 0  58135.0  klenormand0@businessinsider.com   27        42
# 1  96053.0              hrupke1@reuters.com   22        51
# 2  59196.0      gdalgarnowch2@microsoft.com   40        43
# 3  88493.0               cputten3@nymag.com   62        56
# 4  89073.0       astrangman4@bravesites.com   47        45

# %% [markdown]
# ### 10. Delete Columns

# %%
del newdf['Age_Copy']

# %%
newdf.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0          NaN     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  age
# 0  58135.0  klenormand0@businessinsider.com   25
# 1  96053.0              hrupke1@reuters.com   28
# 2  59196.0      gdalgarnowch2@microsoft.com   61
# 3  88493.0               cputten3@nymag.com   28
# 4  89073.0       astrangman4@bravesites.com   40

# %%
# Use the `drop` function to delete the newly created `Age_Copy` column
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0       Putten     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# 4  89073.0       astrangman4@bravesites.com   47

# %% [markdown]
# ### 11. Save Modified DataFrame to New CSV

# %%
# Save the DataFrame to the `Resources` folder
